# %%
from PIL import Image
import cv2
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
import os
from PIL import ImageOps
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
eyes_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')

# %%
frame="happy/2562.jpg"

# %%
i=Image.open(frame)
#grayscale
im2 = ImageOps.grayscale(i) 
faces=face_cascade.detectMultiScale(np.array(im2),1.3,5)
for(x,y,w,h) in faces:
    cv2.rectangle(np.array(im2),(x,y),(x+w,y+h),(255,0,0),2)
#eyes = eyes_cascade.detectMultiScale(np.array(im2)[y:y+h, x:x+w])
#(x,y,w,h)=faces[0]
#for (ex, ey, ew, eh) in eyes:
    #cv2.rectangle(np.array(im2), (x+ex, y+ey), (x+ex+ew, y+ey+eh), 
                #  (255, 255, 255), 1)
rows, cols = np.array(im2).shape[:2]
M = cv2.getRotationMatrix2D((cols/2, rows/2), <angle>, 1)
img_rotated = cv2.warpAffine(face_orig, M, (cols,rows))
plt.imshow(im2)


#faces=face_cascade.detectMultiScale(np.array(im2),1.3,5)

# %%
eyes
# Out:
# array([[34, 39, 40, 40],
#        [91, 35, 39, 39],
#        [50, 96, 39, 39]], dtype=int32)

# %%
faces
# Out:
# array([[ 32,  27, 130, 130]], dtype=int32)

# %%
eyes
# Out:
# array([[74, 34, 30, 30],
#        [24, 33, 32, 32]], dtype=int32)

# %%
type(im2)
# Out:
# PIL.Image.Image

# %%
im2
# Out:
# <PIL.Image.Image image mode=L size=183x275 at 0x7FF1613D3E20>

# %%
angle=

# %%
rows, cols = np.array(im2).shape[:2]
M = cv2.getRotationMatrix2D((cols/2, rows/2), <angle>, 1)
img_rotated = cv2.warpAffine(face_orig, M, (cols,rows))
plt.imshow(im2)
# Out:
#   File "<ipython-input-60-dcc5050523f0>", line 2
#     M = cv2.getRotationMatrix2D((cols/2, rows/2), <angle>, 1)
#                                                   ^
# SyntaxError: invalid syntax

# %%
frame="happy/2561.jpg"
i=Image.open(frame)
#grayscale
im2 = ImageOps.grayscale(i) 
faces=face_cascade.detectMultiScale(np.array(im2),1.3,5)
(x,y,w,h)=faces[0]
crop=np.array(im2)[y:y+h, x:x+w]
s=cv2.resize(crop, (64, 64), interpolation=cv2.INTER_LINEAR)
norm_img = np.zeros((300, 300))
norm_img = cv2.normalize(s, norm_img, 0, 255, cv2.NORM_MINMAX)
PIL_image = Image.fromarray(np.uint8(norm_img)).convert('RGB')
print(PIL_image.size)
#cv2.imwrite('crop.jpg', img_rotated[y-p+1:y+h+p, x-p+1:x+w+p])
# Out:
# (64, 64)

# %%
PIL_image
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7FBD5814A3D0>

# %%
PIL_image.save("corr2.jpg")

# %%
PIL_image
# Out:
# <PIL.Image.Image image mode=RGB size=78x78 at 0x7FF1617EAFD0>

# %%
im2
# Out:
# <PIL.Image.Image image mode=L size=183x275 at 0x7FF1614E4AC0>

# %%
faces
# Out:
# array([[ 28,  63, 151, 151]], dtype=int32)

# %%
for (x,y,w,h) in faces:
    print(x)
    print(y)
    print(w)
    print(h)
# Out:
# 28
# 63
# 151
# 151

# %%
crop=np.array(im2)[y:y+h, x:x+w]

# %%
crop.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-71-8f1e0881fc85> in <module>
# ----> 1 crop.show()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'show'

# %%
plt.imshow(crop)

# %%
im2
# Out:
# <PIL.Image.Image image mode=L size=183x275 at 0x7FF1614E4AC0>

# %%
x
# Out:
# 28

# %%
h
# Out:
# 151

# %%
im2.crop((y,y+h,x,x+w))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     505     try:
# --> 506         fh = fp.fileno()
#     507         fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# SystemError                               Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/PIL/Image.py in _repr_png_(self)
#     670         """
#     671         b = io.BytesIO()
# --> 672         self.save(b, "PNG")
#     673         return b.getvalue()
#     674
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    2156
#    2157         try:
# -> 2158             save_handler(self, fp, filename)
#    2159         finally:
#    2160             # do what we can to clean up
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/PIL/PngImagePlugin.py in _save(im, fp, filename, chunk, save_all)
#    1282         _write_multiple_frames(im, fp, chunk, rawmode)
#    1283     else:
# -> 1284         ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#    1285
#    1286     chunk(fp, b"IEND", b"")
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     512             if o > 0:
#     513                 fp.seek(o)
# --> 514             e.setimage(im.im, b)
#     515             if e.pushes_fd:
#     516                 e.setfd(fp)
#
# SystemError: tile cannot extend outside image
# <PIL.Image.Image image mode=L size=0x0 at 0x7FF1615AFDF0>

# %%
plt.imshow(crop)

# %%
PIL_image = Image.fromarray(np.uint8(crop)).convert('RGB')

#PIL_image = Image.fromarray(crop.astype('uint8'), 'RGB')

# %%
PIL_image
# Out:
# <PIL.Image.Image image mode=RGB size=151x151 at 0x7FF16166A310>

# %%
s=cv2.resize(np.array(PIL_image), (78, 78), interpolation=cv2.INTER_LINEAR)

# %%
type(s)
# Out:
# numpy.ndarray

# %%
plt.imshow(s)

# %%
PIL_im = Image.fromarray(np.uint8(s)).convert('RGB')

# %%
PIL_im
# Out:
# <PIL.Image.Image image mode=RGB size=78x78 at 0x7FF1618FB6D0>

# %%
PIL_im.size
# Out:
# (78, 78)

# %% [markdown]
# ****

# %%
s=cv2.resize(crop, (78, 78), interpolation=cv2.INTER_LINEAR)

# %%
plt.imshow(crop)

# %%
crop
# Out:
# array([[116, 139, 124, ...,  77,  94,  53],
#        [137, 127, 128, ...,  64,  92,  84],
#        [145, 118, 136, ...,  80,  67, 112],
#        ...,
#        [ 11,  13,  21, ...,  14,  13,  14],
#        [ 12,  14,  22, ...,  10,  12,  14],
#        [ 14,  16,  23, ...,   7,  12,  15]], dtype=uint8)

# %%
norm_img = np.zeros((300, 300))
norm_img = cv2.normalize(crop, norm_img, 0, 255, cv2.NORM_MINMAX)

# %%
plt.imshow(norm_img)

# %%
crop
# Out:
# array([[116, 139, 124, ...,  77,  94,  53],
#        [137, 127, 128, ...,  64,  92,  84],
#        [145, 118, 136, ...,  80,  67, 112],
#        ...,
#        [ 11,  13,  21, ...,  14,  13,  14],
#        [ 12,  14,  22, ...,  10,  12,  14],
#        [ 14,  16,  23, ...,   7,  12,  15]], dtype=uint8)

# %%
norm_img
# Out:
# array([[117, 140, 125, ...,  78,  95,  53],
#        [138, 128, 129, ...,  65,  93,  85],
#        [146, 119, 137, ...,  81,  68, 113],
#        ...,
#        [ 11,  13,  21, ...,  14,  13,  14],
#        [ 12,  14,  22, ...,  10,  12,  14],
#        [ 14,  16,  23, ...,   7,  12,  15]], dtype=uint8)

# %%
a=0
for filename in os.listdir("neutral"):
    frame="neutral/"+filename
    if frame=='neutral/.DS_Store':
        pass
    else:
        i=Image.open(frame)
        im2 = ImageOps.grayscale(i) 
        faces=face_cascade.detectMultiScale(np.array(im2),1.3,5)
        if len(faces)!=0:
            a=a+1
            (x,y,w,h)=faces[0]
            crop=np.array(im2)[y:y+h, x:x+w]
            s=cv2.resize(crop, (64, 64), interpolation=cv2.INTER_LINEAR)
            norm_img = np.zeros((300, 300))
            norm_img = cv2.normalize(s, norm_img, 0, 255, cv2.NORM_MINMAX)
            PIL_image = Image.fromarray(np.uint8(norm_img)).convert('RGB')
            PIL_image.save(str(a)+".jpg")
            
        else:
            pass

# %%
frame="happy/620.jpg"
i=Image.open(frame)
#grayscale
im2 = ImageOps.grayscale(i) 
faces=face_cascade.detectMultiScale(np.array(im2),1.3,5)
(x,y,w,h)=faces[0]
crop=np.array(im2)[y:y+h, x:x+w]
s=cv2.resize(crop, (48, 48), interpolation=cv2.INTER_LINEAR)
norm_img = np.zeros((300, 300))
norm_img = cv2.normalize(s, norm_img, 0, 255, cv2.NORM_MINMAX)
PIL_image = Image.fromarray(np.uint8(norm_img)).convert('RGB')
print(PIL_image.size)
PIL_image.show()
#cv2.imwrite('crop.jpg', img_rotated[y-p+1:y+h+p, x-p+1:x+w+p])
# Out:
# (48, 48)
